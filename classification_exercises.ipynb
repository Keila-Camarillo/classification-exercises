# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import pydataset as data
import env
import acquire as acq
import os
import prepare as prep
directory = os.getcwd()

# %% [markdown]
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
df_iris = data.data("iris")

# %% [markdown]
# * print the first 3 rows

# %%
print(df_iris.head(3))
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# * print the number of rows and columns (shape)

# %%
print(df_iris.shape)
# Out:
# (150, 5)

# %% [markdown]
# * print the column names

# %%
print(df_iris.columns)
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# * print the data type of each column

# %%
print(df_iris.dtypes)
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %% [markdown]
# * print the summary statistics for each of the numeric variables

# %%
print(df_iris.describe())
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# 5. Read the data from this google sheet into a dataframe, df_google.

# %% [markdown]
# * print the first 3 rows

# %%
google_sheet = "https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357"
csv_export_url = google_sheet.replace("/edit#gid=", "/export?format=csv&gid=")
df_google = pd.read_csv(csv_export_url)
print(df_google.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# * print the number of rows and columns

# %%
print(df_google.shape)
# Out:
# (891, 12)

# %% [markdown]
# * print the column names

# %%
print(df_google.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# * print the data type of each column

# %%
print(df_google.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# * print the summary statistics for each of the numeric variables

# %%
print(df_google.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# * print the unique values for each of your categorical variables

# %%
print(df_google.Sex.unique())
# Out:
# ['male' 'female']

# %%
print(df_google.SibSp.unique())
# Out:
# [1 0 3 4 2 5 8]

# %%
print(df_google.Embarked.unique())
# Out:
# ['S' 'C' 'Q' nan]

# %%
print(df_google.Survived.unique())
# Out:
# [0 1]

# %%
print(df_google.Pclass.unique())
# Out:
# [3 1 2]

# %%
print(df_google.Parch.unique())
# Out:
# [0 1 2 5 3 4 6]

# %% [markdown]
# 6. Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
df_google.to_excel("df_excel.xlsx")

# %%
df_excel = pd.read_excel("df_excel.xlsx", index_col=0)

# %% [markdown]
# * assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample =  df_excel.head(100)

# %% [markdown]
# * print the number of rows of your original dataframe

# %%
print(df_excel.shape[0])
# Out:
# 891

# %% [markdown]
# * print the first 5 column names

# %%
print(df_excel.iloc[:, :5])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex
# 0                                Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                 Heikkinen, Miss. Laina  female
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                               Allen, Mr. William Henry    male
# ..                                                   ...     ...
# 886                                Montvila, Rev. Juozas    male
# ...

# %% [markdown]
# * print the column names that have a data type of object

# %%
df_excel.select_dtypes(include="object").columns.to_list()
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df_excel.select_dtypes(exclude="object").columns.to_list()
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# * compute the range for each of the numeric variables.

# %%
df_excel.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
directory = os.getcwd()

# %%
acq.get_titanic_data("select * from passengers", directory)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %%
acq.get_iris_data("select * from measurements join species using(species_id)", directory)
# Out:
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# 5             1               6           5.4          3.9           1.7
# 6             1               7           4.6          3.4           1.4
# 7             1               8           5.0          3.4           1.5
# 8             1               9           4.4          2.9           1.4
# 9             1              10           4.9          3.1           1.5
# 10            1              11           5.4          3.7           1.5
# 11            1              12           4.8          3.4           1.6
# ...

# %%
acq.get_telco_data(''' select * from customers
left join customer_churn
using (customer_id)
left join customer_signups
using (customer_id)
join internet_service_types
using (internet_service_type_id)
join payment_types
using (payment_type_id);''', directory)
# Out:
#       payment_type_id  internet_service_type_id customer_id  gender  \
# 0                   2                         1  0002-ORFBO  Female
# 1                   2                         1  0003-MKNFE    Male
# 2                   1                         2  0004-TLHLJ    Male
# 3                   1                         2  0011-IGKFF    Male
# 4                   2                         2  0013-EXCHZ  Female
# ...               ...                       ...         ...     ...
# 7038                2                         1  9987-LUTYD  Female
# 7039                1                         2  9992-RRAMN    Male
# 7040                2                         1  9992-UJOEL    Male
# 7041                2                         1  9993-LHIEB    Male
# 7042                1                         1  9995-HOTOH    Male
#
#       senior_citizen partner dependents  tenure phone_service  \
# 0                  0     Yes        Yes       9           Yes
# ...

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# Part I

# %% [markdown]
# Section 1 - iris_db: Using iris data from our mySQL server and the methods used in the lesson above:
#
# 1. Acquire, prepare & split your data.

# %%
iris_train, iris_validate, iris_test = prep.get_prep_split_iris()

# %% [markdown]
# 2. Univariate Stats
#
# * For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).

# %%
iris_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 70            5.9          3.2           4.8          1.8  versicolor
# 123           6.3          2.7           4.9          1.8   virginica
# 87            6.3          2.3           4.4          1.3  versicolor
# 3             4.6          3.1           1.5          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 53            5.5          2.3           4.0          1.3  versicolor
# 20            5.4          3.4           1.7          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 81            5.5          2.4           3.7          1.0  versicolor
# 88            5.6          3.0           4.1          1.3  versicolor
# ...

# %%
# sort through which varibles are caterorical or numeric
col_cat = [] #this is for my categorical varibles
col_num = [] #this is for my numeric varibles

for col in iris_train.columns[:-2]:
    print(col)
    if iris_train[col].dtype == 'O':
        col_cat.append(col)
    else:
        if len(iris_train[col].unique()) < 4: #making anything with less than 4 unique values a catergorical value
            col_cat.append(col)
        else:
            col_num.append(col)
# Out:
# sepal_length
# sepal_width
# petal_length
# petal_width
# species

# %%
col_cat, col_num
# Out:
# (['species'], ['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

# %%
for col in col_num:
    print(col.upper())
    print(iris_train[col].value_counts())
    print(iris_train[col].hist())
    plt.show()
# Out:
# SEPAL_LENGTH
# 5.0    7
# 6.4    7
# 5.7    6
# 5.8    6
# 5.4    5
# 6.3    5
# 5.5    4
# 6.9    4
# 5.9    3
# 4.8    3
# 4.9    3
# 5.1    3
# 7.2    3
# 6.0    3
# 6.7    3
# 5.6    3
# 6.5    3
# 6.2    2
# 6.1    2
# 5.2    2
# 4.6    2
# 7.7    1
# 6.6    1
# 7.9    1
# 6.8    1
# 5.3    1
# 4.4    1
# 7.3    1
# 7.4    1
# 7.0    1
# 4.5    1
# 4.7    1
# Name: sepal_length, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# SEPAL_WIDTH
# 3.0    14
# 2.8     9
# 3.2     8
# 2.7     8
# 3.4     8
# 2.9     7
# 3.1     7
# 3.8     4
# 2.6     3
# 2.3     3
# 3.5     3
# 2.5     3
# 2.4     2
# 3.6     2
# 3.3     2
# 3.9     2
# 4.4     1
# 4.1     1
# 3.7     1
# 2.2     1
# 4.0     1
# Name: sepal_width, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# PETAL_LENGTH
# 1.5    7
# 1.6    6
# 5.1    6
# 1.4    5
# 4.5    4
# 1.7    4
# 4.2    4
# 5.6    4
# 1.3    4
# 3.9    3
# 5.8    3
# 4.6    3
# 4.0    3
# 1.9    2
# 5.3    2
# 5.5    2
# 1.2    2
# 4.8    2
# 6.0    2
# ...

# %%
for col in col_num:
    print(col.upper())
    print(iris_train[col].describe())
# Out:
# SEPAL_LENGTH
# count    90.000000
# mean      5.875556
# std       0.792282
# min       4.400000
# 25%       5.225000
# 50%       5.800000
# 75%       6.400000
# max       7.900000
# Name: sepal_length, dtype: float64
# SEPAL_WIDTH
# count    90.000000
# mean      3.070000
# std       0.436135
# min       2.200000
# 25%       2.800000
# 50%       3.000000
# 75%       3.375000
# max       4.400000
# Name: sepal_width, dtype: float64
# PETAL_LENGTH
# count    90.000000
# mean      3.782222
# std       1.742114
# min       1.200000
# 25%       1.600000
# 50%       4.250000
# 75%       5.100000
# max       6.900000
# Name: petal_length, dtype: float64
# PETAL_WIDTH
# count    90.000000
# mean      1.203333
# std       0.755422
# min       0.100000
# 25%       0.400000
# 50%       1.300000
# 75%       1.800000
# max       2.500000
# Name: petal_width, dtype: float64

# %% [markdown]
# Takeaways
# * sepal_length and sepal_width have normal distribution
# * petal_width and petal_length does not have normal distribution

# %% [markdown]
# * For each species (categorical variable): create a frequency table and a bar plot of those frequencies.

# %%
for col in col_cat:
    print(col.upper())
    print(iris_train[col].value_counts())
    print(iris_train[col].value_counts(normalize=True))
    iris_train[col].value_counts().plot.bar()
    plt.show()
    print()
# Out:
# SPECIES
# versicolor    30
# virginica     30
# setosa        30
# Name: species, dtype: int64
# versicolor    0.333333
# virginica     0.333333
# setosa        0.333333
# Name: species, dtype: float64

# %% [markdown]
# Takeaways
# * there are no noteable issues
# * catergorical variables
# * target variable is flower name

# %% [markdown]
# * Document takeaways & any actions.

# %% [markdown]
# 3. Bivariate Stats

# %% [markdown]
# * Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).

# %% [markdown]
# x = specices (name)
#
# y = measurement

# %%
sns.boxplot(data=iris_train, x='species', y='sepal_length')
plt.show()

# %%
sns.boxplot(data=iris_train, x='species', y='sepal_width')
plt.show()

# %%
sns.boxplot(data=iris_train, x='species', y='petal_length')
plt.show()

# %%
sns.boxplot(data=iris_train, x='species', y='petal_width')
plt.show()

# %% [markdown]
# Takeaway (TA):
#   * virginica has an outlier
#   * the species appears to be associated to their sepal_length
#   * setosa has apears to have a smaller petal_width and petal_length in comparison to other species

# %% [markdown]
# * For each measurement type, compute the descriptive statistics for each species.

# %%
train_versicolor_desc = iris_train[iris_train.species == "versicolor" ].describe().T
train_virginica_desc = iris_train[iris_train.species == "virginica" ].describe().T
train_setosa_desc = iris_train[iris_train.species == "setosa" ].describe().T

# %%
train_setosa_desc, train_versicolor_desc, train_virginica_desc
# Out:
# (                    count      mean       std  min    25%  50%    75%  max
#  sepal_length         30.0  5.070000  0.356371  4.4  4.825  5.0  5.375  5.8
#  sepal_width          30.0  3.446667  0.420782  2.3  3.200  3.4  3.775  4.4
#  petal_length         30.0  1.510000  0.178789  1.2  1.400  1.5  1.600  1.9
#  petal_width          30.0  0.266667  0.121296  0.1  0.200  0.2  0.375  0.6
#  species_versicolor   30.0  0.000000  0.000000  0.0  0.000  0.0  0.000  0.0
#  species_virginica    30.0  0.000000  0.000000  0.0  0.000  0.0  0.000  0.0,
#                      count      mean       std  min    25%   50%    75%  max
#  sepal_length         30.0  5.910000  0.476590  4.9  5.600  5.80  6.175  7.0
#  sepal_width          30.0  2.806667  0.281539  2.3  2.625  2.80  3.000  3.4
#  petal_length         30.0  4.273333  0.409317  3.3  4.000  4.25  4.575  5.1
#  petal_width          30.0  1.320000  0.193694  1.0  1.200  1.30  1.475  1.8
# ...

# %% [markdown]
# * For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.

# %% [markdown]
# Independent T- Test

# %%
train_versicolor_petal_width = iris_train[iris_train.species == "versicolor" ].petal_width
train_virginica_petal_width = iris_train[iris_train.species == "virginica" ].petal_width

# %%
train_versicolor_petal_width.hist()
plt.show()

# %%
train_virginica_petal_width.hist()
plt.show()

# %%
# check variances = close enough
train_versicolor_sepal_length.var(), train_setosa_sepal_length.var(), train_virginica_sepal_length.var()
# Out:
# (0.2271379310344827, 0.127, 0.28464367816091957)

# %% [markdown]
# * they are not normal dist
# * meet the 30
# * equal variances

# %% [markdown]
# $H_o$: The versicolor petal width is equal to virginica petal width
#
# $H_a$: The versicolor petal width is not equal to virginica petal width

# %%
s, p = stats.mannwhitneyu(train_versicolor_petal_width, train_virginica_petal_width)

# %%
alpha = 0.05

# %%
if p < alpha:
    print("We reject null hypothesis")
else:
    print("We fail to reject null hypothesis")
# Out:
# We reject null hypothesis

# %% [markdown]
# TA
# * there is a difference in petal widths for virginica and versicolor

# %% [markdown]
# Q: Is there a difference in petal lengths for virginica and versicolor

# %%
train_virginica_petal_length = iris_train[iris_train.species == "virginica" ].petal_length
train_versicolor_petal_length = iris_train[iris_train.species == "versicolor" ].petal_length

# %%
train_virginica_petal_length.hist()
plt.show()

# %%
train_versicolor_petal_length.hist()
plt.show()

# %% [markdown]
# * they are normal distribution
# * virginca has an outlier

# %% [markdown]
# $H_o$: The versicolor petal length is equal to virginica petal length
#
# $H_a$: The versicolor petal length is not equal to virginica petal length

# %%
train_versicolor_petal_length.var(), train_virginica_petal_length.var()
# Out:
# (0.16754022988505746, 0.24240229885057474)

# %%
s2, p2 = stats.mannwhitneyu(train_versicolor_petal_length, train_virginica_petal_length)

# %%
if p2 < alpha:
    print("We reject null hypothesis")
else:
    print("We fail to reject null hypothesis")
# Out:
# We reject null hypothesis

# %% [markdown]
# TA
#
# * there is a difference in petal lengths for virginica and versicolor

# %% [markdown]
# Q: Is there a difference in sepal lengths for virginica and versicolor?

# %%
train_virginica_sepal_length = iris_train[iris_train.species == "virginica" ].sepal_length
train_versicolor_sepal_length = iris_train[iris_train.species == "versicolor" ].sepal_length

# %%
train_versicolor_sepal_length.hist()
plt.show()

# %%
train_virginica_sepal_length.hist()
plt.show()

# %%
train_versicolor_sepal_length.var(), train_virginica_sepal_length.var()
# Out:
# (0.2271379310344827, 0.28464367816091957)

# %%
* they appear normal distribution
* virginca has an outlier
* equal var

# %% [markdown]
# $H_o$: The versicolor sepal length is equal to virginica sepal length
#
# $H_a$: The versicolor sepal length is not equal to virginica sepal length

# %%
s3, p3 = stats.mannwhitneyu(train_versicolor_sepal_length, train_virginica_sepal_length)

# %%
if p3 < alpha:
    print("We reject null hypothesis")
else:
    print("We fail to reject null hypothesis")
# Out:
# We reject null hypothesis

# %% [markdown]
# TA
#
# * there is a difference in sepal lengths for virginica and versicolor

# %%
Q: Is there a difference in sepal widths for virginica and versicolor

# %%
train_virginica_sepal_width = iris_train[iris_train.species == "virginica" ].sepal_width
train_versicolor_sepal_width = iris_train[iris_train.species == "versicolor" ].sepal_width

# %%
train_versicolor_sepal_width.hist()
plt.show()

# %%
train_virginica_sepal_width.hist()
plt.show()

# %%
train_versicolor_sepal_width.var(), train_virginica_sepal_width.var()
# Out:
# (0.07926436781609197, 0.09564367816091952)

# %%
* they appear not normal distribution and normal
* virginca has an outlier
* equal var

# %% [markdown]
# $H_o$: The versicolor sepal width is equal to virginica sepal width
#
# $H_a$: The versicolor sepal width is not equal to virginica sepal width

# %%
s4, p4 = stats.mannwhitneyu(train_versicolor_sepal_width, train_virginica_sepal_width)

# %%
stats.ttest_ind(train_versicolor_sepal_width, train_virginica_sepal_width)
# Out:
# Ttest_indResult(statistic=-1.9644771987448686, pvalue=0.05427209052014701)

# %%
if p4 < alpha:
    print("We reject null hypothesis")
else:
    print("We fail to reject null hypothesis")
# Out:
# We fail to reject null hypothesis

# %% [markdown]
# The vericolor and virginica sepal width are not significantly different

# %% [markdown]
# * Document takeaways & any actions.

# %% [markdown]
# 4. Multivariate Stats
#
# * Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
sns.pairplot(iris_train, hue="species", corner=True)
plt.show()

# %% [markdown]
# * Visualize two numeric variables of the species. Hint: sns.relplot with hue or col

# %%
sns.relplot(data=iris_train, x="petal_width", y="sepal_width", col="species")

# %% [markdown]
# * Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization. (SKIPPED)

# %%
sns.swarmplot(data=iris_train, x="sepal_length", y="petal_width",hue="species")
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# * Ask a specific question of the data, such as: is the sepal area signficantly different in virginica compared to setosa? Answer the question through both a plot and using a mann-whitney or t-test. If you use a t-test, be sure assumptions are met (independence, normality, equal variance).
#
# * Document takeaways and any actions.

# %% [markdown]
# Q: Is the sepal area signficantly different in virginica compared to setosa?

# %% [markdown]
# * sepal_area = sepal len * sepal wid (continous)
# * virginica vs setosa (cat vs cat)

# %%
iris_train["sepal_area"] = iris_train.sepal_length * iris_train.sepal_width

# %%
setosa_sepal_area = pd.Series(iris_train[iris_train.species == "setosa"].sepal_area)
virginica_sepal_area = iris_train[iris_train.species == "virginica"].sepal_area

# %%
setosa_sepal_area.hist()
# Out:
# <AxesSubplot:>

# %%
setosa_sepal_area
# Out:
# 3     14.26
# 15    25.08
# 20    18.36
# 6     15.64
# 31    18.36
# 4     18.00
# 18    21.66
# 36    19.25
# 41    10.35
# 23    16.83
# 35    16.00
# 1     14.70
# 16    21.06
# 32    21.32
# 48    19.61
# 25    15.00
# 12    14.40
# 46    19.38
# 43    17.50
# 26    17.00
# 8     12.76
# 24    16.32
# 14    23.20
# 40    17.50
# 9     15.19
# 7     17.00
# 5     21.06
# 11    16.32
# 29    15.04
# 44    19.38
# Name: sepal_area, dtype: float64

# %%
virginica_sepal_area.hist()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=iris_train, x="species", y="sepal_area")
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_area'>

# %%
* there appears to be a significant difference between virginica and setosa sepal area

# %%
virginica_sepal_area.var(), setosa_sepal_area.var() # close enough var
# Out:
# (10.094875402298852, 10.065846091954024)

# %% [markdown]
# * they appear normal distribution and normal
# * equal var
# * independent

# %% [markdown]
# $H_o$: The setosa sepal area is equal to virginica sepal area
#
# $H_a$: The setosa sepal area is not equal to virginica sepal area

# %%
t5, p5 = stats.ttest_ind(virginica_sepal_area, setosa_sepal_area)

# %%
if p5 < alpha:
    print("We reject null hypothesis")
else:
    print("We fail to reject null hypothesis")
# Out:
# We reject null hypothesis

# %% [markdown]
# TA
# * the sepal area of setosa and viriginica are significantly different

# %% [markdown]
# # Part III

# %% [markdown]
# * Explore your telco data to discover drivers of churn

# %%
telco_train, telco_validate, telco_test = prep.get_prep_split_telco()

# %%
telco_train
# Out:
#       gender  senior_citizen partner dependents  tenure phone_service  \
# 5911    Male               0      No        Yes      26            No
# 2479  Female               0     Yes         No      47           Yes
# 5889  Female               0      No         No       1           Yes
# 6087    Male               0      No         No      69            No
# 785   Female               0      No         No      51           Yes
# ...      ...             ...     ...        ...     ...           ...
# 6102  Female               0     Yes         No       2           Yes
# 356   Female               1      No         No      52            No
# 1756    Male               0      No         No       4           Yes
# 2127    Male               0      No         No      35           Yes
# 3586  Female               0      No         No      10           Yes
#
#         multiple_lines      online_security        online_backup  \
# ...

# %% [markdown]
# * Determine if certain columns should be dropped

# %%
col_cat = [] #this is for my categorical varibles
col_num = [] #this is for my numeric varibles

for col in telco_train.columns[:-10]:
    if telco_train[col].dtype == 'O':
        col_cat.append(col)
    else:
        if len(telco_train[col].unique()) < 4: #making anything with less than 4 unique values a catergorical value
            col_cat.append(col)
        else:
            col_num.append(col)

# %%
for col in col_cat:
    print(col.upper())
    print(telco_train[col].value_counts())
    print(telco_train[col].value_counts(normalize=True))
    telco_train[col].value_counts().plot.bar()
    plt.show()
    print()
# Out:
# GENDER
# Male      2149
# Female    2076
# Name: gender, dtype: int64
# Male      0.508639
# Female    0.491361
# Name: gender, dtype: float64
# SENIOR_CITIZEN
# 0    3541
# 1     684
# Name: senior_citizen, dtype: int64
# 0    0.838107
# 1    0.161893
# Name: senior_citizen, dtype: float64
# PARTNER
# No     2161
# Yes    2064
# Name: partner, dtype: int64
# No     0.511479
# Yes    0.488521
# Name: partner, dtype: float64
# DEPENDENTS
# No     2931
# Yes    1294
# Name: dependents, dtype: int64
# No     0.693728
# Yes    0.306272
# Name: dependents, dtype: float64
# PHONE_SERVICE
# Yes    3832
# No      393
# Name: phone_service, dtype: int64
# Yes    0.906982
# No     0.093018
# Name: phone_service, dtype: float64
# MULTIPLE_LINES
# No                  2025
# Yes                 1807
# No phone service     393
# Name: multiple_lines, dtype: int64
# No                  0.479290
# Yes                 0.427692
# No phone service    0.093018
# Name: multiple_lines, dtype: float64
# ...

# %% [markdown]
# TA
#
# there are no noteable issues
# these are my categorical variables
# churn is my target variable, and has more people who didn't churn

# %% [markdown]
# * Determine if it would be valuable to bin some numeric columns

# %%
for col in col_num:
    print(col.upper())
    print(telco_train[col].value_counts())
    print(telco_train[col].hist())
    plt.show()
# Out:
# TENURE
# 1     358
# 72    217
# 2     143
# 3     112
# 71    106
# 4     103
# 7      88
# 13     75
# 10     73
# 70     73
# 15     71
# 12     71
# 9      70
# 8      69
# 11     68
# 5      67
# 6      66
# 18     61
# 66     58
# 24     57
# 68     57
# 52     56
# 67     55
# 69     55
# 17     51
# 20     50
# 61     50
# 47     49
# 46     49
# 22     49
# 32     49
# 23     48
# 65     48
# 19     47
# 26     47
# 35     47
# 27     46
# 16     46
# 54     46
# 25     45
# 29     45
# 51     45
# 60     44
# 62     44
# 55     44
# 41     44
# 63     43
# 49     43
# 64     43
# 37     42
# 50     42
# 40     42
# 56     41
# 14     40
# 53     40
# 34     38
# 57     38
# 42     37
# 31     36
# 48     36
# 38     35
# 58     35
# 59     35
# 30     34
# 21     33
# 33     33
# 28     32
# 39     32
# 43     32
# 44     31
# 45     31
# 36     30
# 0       9
# Name: tenure, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# MONTHLY_CHARGES
# 20.05     36
# 19.85     35
# ...

# %% [markdown]
# * bin =  tenure, signup_date
#
# TA
#
# * signp_date has a significant increase in 2016 and 2022
# * total_charges has a right tail

# %% [markdown]
# Q: Is whether or not a customer churns independent of their choice on paperless billing?

# %% [markdown]
# $H_o$: churn is independent of paperless billing
#
# $H_a$: churn is dependent of paperless billing

# %%
observed = pd.crosstab(telco_train.churn, telco_train.paperless_billing_Yes)

# %%
observed
# Out:
# paperless_billing_Yes     0     1
# churn
# No                     1433  1671
# Yes                     283   838

# %%
def chi2_test(table, variables=False):
    chi2, p, degf, expected = stats.chi2_contingency(table)
    print('Observed')
    print(table.values)
    print('\nExpected')
    print(table.astype(int))
    print('\n----')
    print(f'chi^2 = {chi2:.4f}')
    print(f'p     = {p}')
    if variables:
        return  chi2, p, degf, expected
    else:
        return

# %%
chi2_test(observed)
# Out:
# Observed
# [[1433 1671]
#  [ 283  838]]
#
# Expected
# paperless_billing_Yes     0     1
# churn
# No                     1433  1671
# Yes                     283   838
#
# ----
# chi^2 = 148.5845
# p     = 3.5348504574964642e-34

# %%
if p < alpha:
    print("We reject null hypothesis")
else:
    print("We fail to reject null hypothesis")
# Out:
# We reject null hypothesis

# %% [markdown]
# There is a some relationship between paperless billing and churned customers

# %% [markdown]
# * Determine if it would be valuable to combine multiple columns into one.
#
# > dependents and partners could possibly be combined

# %%
telco_train
# Out:
#       gender  senior_citizen partner dependents  tenure phone_service  \
# 5911    Male               0      No        Yes      26            No
# 2479  Female               0     Yes         No      47           Yes
# 5889  Female               0      No         No       1           Yes
# 6087    Male               0      No         No      69            No
# 785   Female               0      No         No      51           Yes
# ...      ...             ...     ...        ...     ...           ...
# 6102  Female               0     Yes         No       2           Yes
# 356   Female               1      No         No      52            No
# 1756    Male               0      No         No       4           Yes
# 2127    Male               0      No         No      35           Yes
# 3586  Female               0      No         No      10           Yes
#
#         multiple_lines      online_security        online_backup  \
# ...

# %% [markdown]
# Q: Is whether or not a customer churns independent of whether they have dependents?
#
# $H_o$: churn is independent of customer's having dependents
#
# $H_a$: churn is dependent of customer's having dependents

# %%
observed2 = pd.crosstab(telco_train.churn, telco_train.dependents)

# %%
chi2_test(observed2)
# Out:
# Observed
# [[2013 1091]
#  [ 918  203]]
#
# Expected
# dependents    No   Yes
# churn
# No          2013  1091
# Yes          918   203
#
# ----
# chi^2 = 111.7405
# p     = 4.0728740930257527e-26

# %% [markdown]
# we reject the null hypothesis and churn is dependent of customer's having dependents

# %% [markdown]
# What are your drivers of churn? dependednts and paperless billing
#
# Does it make sense to combine any features? No
#
# Do you find any surprises?
#
# Document any and all findings and takeaways in your notebook using markdown.
